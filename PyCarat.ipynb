# %%
import numpy as np
import pandas as pd

# %%
#Import dataset
data = pd.read_csv("C:\\Users\\SHASHI\\Desktop\\Academic\\UOC 4\\Statistical Learning\\Project 1\\DATASET\\Breast_Cancer.csv")

# %%
#Set id as the index 
data.set_index(['id'] , inplace =  True)

# %%
del data['Unnamed: 32']

# %%
#Convert diagnosis to binary
data['diagnosis'] = data['diagnosis'].map({'M' :1, 'B': 0})

# %%
from pycaret.classification import *
exp1 = setup(data, target = 'diagnosis')
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_8072a47e_c077_11ea_aee0_74c63bebd9f4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8072a47e_c077_11ea_aee0_74c63bebd9f4level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_8072a47e_c077_11ea_aee0_74c63bebd9f4row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_8072a47e_c077_11ea_aee0_74c63bebd9f4row0_col1" class="data row0 col1" >4256</td>
#             </tr>
#             <tr>
#                         <th id="T_8072a47e_c077_11ea_aee0_74c63bebd9f4level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_8072a47e_c077_11ea_aee0_74c63bebd9f4row1_col0" class="data row1 col0" >Target Type</td>
# ...

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_b89273ee_c077_11ea_a532_74c63bebd9f4 th {
#           text-align: left;
#     }    #T_b89273ee_c077_11ea_a532_74c63bebd9f4row0_col0 {
#             text-align:  left;
#         }    #T_b89273ee_c077_11ea_a532_74c63bebd9f4row0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_b89273ee_c077_11ea_a532_74c63bebd9f4row0_col2 {
#             : ;
#             text-align:  left;
#         }    #T_b89273ee_c077_11ea_a532_74c63bebd9f4row0_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_b89273ee_c077_11ea_a532_74c63bebd9f4row0_col4 {
#             : ;
#             text-align:  left;
#         }    #T_b89273ee_c077_11ea_a532_74c63bebd9f4row0_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_b89273ee_c077_11ea_a532_74c63bebd9f4row0_col6 {
#             background-color:  yellow;
#             text-align:  left;
# ...

# %%
xgboost = create_model('xgboost')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9500  0.9947  0.9333  0.9333  0.9333  0.8933
# 1       0.9500  0.9360  0.8667  1.0000  0.9286  0.8904
# 2       0.9500  0.9893  0.8667  1.0000  0.9286  0.8904
# 3       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 4       0.9250  0.9840  0.9333  0.8750  0.9032  0.8421
# 5       0.9250  0.9920  0.9333  0.8750  0.9032  0.8421
# 6       0.9750  0.9973  0.9333  1.0000  0.9655  0.9459
# 7       0.9500  0.9947  0.9333  0.9333  0.9333  0.8933
# 8       0.9744  0.9943  0.9286  1.0000  0.9630  0.9434
# 9       0.9487  0.9943  0.9286  0.9286  0.9286  0.8886
# Mean    0.9548  0.9877  0.9257  0.9545  0.9387  0.9030
# SD      0.0218  0.0177  0.0358  0.0496  0.0282  0.0458

# %%
tuned_xgboost = tune_model('xgboost')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9250  0.9920  0.9333  0.8750  0.9032  0.8421
# 1       0.9250  0.9547  0.8000  1.0000  0.8889  0.8333
# 2       0.9500  0.9920  0.8667  1.0000  0.9286  0.8904
# 3       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 4       0.9000  0.9760  0.8667  0.8667  0.8667  0.7867
# 5       0.9000  0.9893  0.9333  0.8235  0.8750  0.7922
# 6       0.9750  0.9947  0.9333  1.0000  0.9655  0.9459
# 7       0.9500  0.9973  0.9333  0.9333  0.9333  0.8933
# 8       0.9744  0.9943  1.0000  0.9333  0.9655  0.9451
# 9       0.9487  0.9886  0.9286  0.9286  0.9286  0.8886
# Mean    0.9448  0.9879  0.9195  0.9360  0.9255  0.8818
# SD      0.0311  0.0127  0.0580  0.0613  0.0408  0.0658

# %%
evaluate_model(xgboost)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
save_model(tuned_xgboost,model_name = 'c:/Users/SHASHI/deployment_28042020')
# Out:
# Transformation Pipeline and Model Succesfully Saved

# %%
deployment_28042020 = load_model('deployment_28042020')
# Out:
# Transformation Pipeline and Model Sucessfully Loaded

# %%
deployment_28042020
# Out:
# [Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        ml_usecase='classification',
#                                        numerical_features=[], target='diagnosis',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  numeric_strategy='mean',
#                                  target_variable=None)),
#                  ('new_levels1',
#                   New_Catagorical_...
#                  ('group', Empty()), ('nonliner', Empty()), ('scaling', Empty()),
#                  ('P_transform', Empty()), ('pt_target', Empty()),
#                  ('binn', Empty()), ('rem_outliers', Empty()),
#                  ('cluster_all', Empty()),
# ...
